# %% [markdown]
# # Descriptive statistics

# %%
# imported basic libraries
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data=sns.load_dataset("iris") # loaded iris data

# %%
# getting the builtin datasets of seaborn.
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Mean
data["sepal_length"].mean()
# Out:
# 5.843333333333334

# %%
# Median
data["sepal_length"].median()
# Out:
# 5.8

# %%
# standard deviation
data["sepal_length"].std()
# Out:
# 0.8280661279778629

# %%
# variance
data["sepal_length"].var()
# Out:
# 0.6856935123042505

# %%
# min
data["sepal_length"].min()
# Out:
# 4.3

# %%
# max
data["sepal_length"].max()
# Out:
# 7.9

# %%
# range
range=data["sepal_length"].max()-data["sepal_length"].min()
print(range)
# Out:
# 3.6000000000000005

# %%
# skew
data['sepal_length'].skew()
# data is normal since 0.3 lies within -0.5 and 0.5
# Out:
# 0.3149109566369728

# %%
sns.displot(x="sepal_length",data=data,kde=True)

# %%
# kurt
data['sepal_length'].kurt()
# kurtosis is less than 3 , less peaked
# Out:
# -0.5520640413156395

# %%
# lower quartile
Q1=data['sepal_length'].quantile(0.25)
Q1
# Out:
# 5.1

# %%
# upper quartile
Q3=data['sepal_length'].quantile(0.75)
Q3
# Out:
# 6.4

# %%
# middle quartile
Q2=data['sepal_length'].quantile(0.5)
Q2
# Out:
# 5.8

# %%
# IQR=Q3-Q1
IQR=Q3-Q1
IQR
# Out:
# 1.3000000000000007

# %%
d1=data.drop(['species'], axis=1)

# %%
# corr
tc=d1.corr()

# %%
tc
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
data['sepal_length'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    5.1
# 0.50    5.8
# 0.75    6.4
# Name: sepal_length, dtype: float64

# %%
##Heat map
## Heatmap is defined as a graphical representation of data using colors to visualize the value of the matrix.
## In this, to represent more common values or higher activities brighter colors basically reddish colors are used and 
## to represent less common or activity values, darker colors are preferred
import matplotlib.pyplot as plt
# correlation between the different parameters 
tc = d1.corr()
  
tc
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
import matplotlib.pyplot as plt

# %%
# !pip install seaborn --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\programdata\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\programdata\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\programdata\anaconda3\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\programdata\anaconda3\lib\site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
tc
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(tc,annot=True)
plt.show()

# %%
data.describe()   #gives you statistical information about all continuous variables
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# !pip install skimpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: skimpy in c:\users\aarti salunkhe\appdata\roaming\python\python312\site-packages (0.0.15)
# Requirement already satisfied: Pygments<3.0.0,>=2.10.0 in c:\programdata\anaconda3\lib\site-packages (from skimpy) (2.15.1)
# Requirement already satisfied: click<9.0.0,>=8.1.6 in c:\programdata\anaconda3\lib\site-packages (from skimpy) (8.1.7)
# Requirement already satisfied: ipykernel<7.0.0,>=6.7.0 in c:\programdata\anaconda3\lib\site-packages (from skimpy) (6.28.0)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in c:\programdata\anaconda3\lib\site-packages (from skimpy) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=2.0.3 in c:\programdata\anaconda3\lib\site-packages (from skimpy) (2.2.2)
# Requirement already satisfied: polars<0.21,>=0.19 in c:\users\aarti salunkhe\appdata\roaming\python\python312\site-packages (from skimpy) (0.20.31)
# Requirement already satisfied: pyarrow<17,>=13 in c:\programdata\anaconda3\lib\site-packages (from skimpy) (14.0.2)
# Requirement already satisfied: rich<14.0,>=10.9 in c:\programdata\anaconda3\lib\site-packages (from skimpy) (13.3.5)
# Requirement already satisfied: typeguard==4.2.1 in c:\users\aarti salunkhe\appdata\roaming\python\python312\site-packages (from skimpy) (4.2.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\programdata\anaconda3\lib\site-packages (from typeguard==4.2.1->skimpy) (4.11.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click<9.0.0,>=8.1.6->skimpy) (0.4.6)
# Requirement already satisfied: comm>=0.1.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\programdata\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (8.25.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\programdata\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\programdata\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.6.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (23.2)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\programdata\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\programdata\anaconda3\lib\site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2023.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from rich<14.0,>=10.9->skimpy) (2.2.0)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (3.0.43)
# Requirement already satisfied: stack-data in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\programdata\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel<7.0.0,>=6.7.0->skimpy) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\programdata\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel<7.0.0,>=6.7.0->skimpy) (305.1)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14.0,>=10.9->skimpy) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.0.3->skimpy) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.8.3)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.5)
# Requirement already satisfied: executing in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.8.3)
# Requirement already satisfied: asttokens in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (2.0.5)
# Requirement already satisfied: pure-eval in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.2)

# %%
from skimpy import skim
skim(data)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 150    │ │ float64     │ 4     │                                                          │
# │ │ Number of columns │ 5      │ │ string      │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━━━━┓  │
# │ ┃ column_name       ┃ NA   ┃ NA %   ┃ mean     ┃ sd        ┃ p0    ┃ p25   ┃ p50    ┃ p75  ┃ p100  ┃ hist    ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━━━━┩  │
# │ │ sepal_length      │    0 │      0 │    5.843 │    0.8281 │   4.3 │   5.1 │    5.8 │  6.4 │   7.9 │ ▃▇▇▇▅▂  │  │
# │ │ sepal_width       │    0 │      0 │    3.057 │    0.4359 │     2 │   2.8 │      3 │  3.3 │   4.4 │ ▁▇▇▇▂▁  │  │
# │ │ petal_length      │    0 │      0 │    3.758 │     1.765 │     1 │   1.6 │   4.35 │  5.1 │   6.9 │ ▇ ▂▇▆▂  │  │
# │ │ petal_width       │    0 │      0 │    1.199 │    0.7622 │   0.1 │   0.3 │    1.3 │  1.8 │   2.5 │ ▇ ▂▆▅▃  │  │
# │ └───────────────────┴──────┴────────┴──────────┴───────────┴───────┴───────┴────────┴──────┴───────┴─────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name               ┃ NA      ┃ NA %       ┃ words per row                ┃ total words              ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ species                   │       0 │          0 │                            1 │                      150 │  │
# │ └───────────────────────────┴─────────┴────────────┴──────────────────────────────┴──────────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# # QQ Plot implementation¶

# %%
import numpy as np 
import statsmodels.api as sm 
import pylab as py 
  
# np.random generates different random numbers everytime the code is executed.
data_points = np.random.normal(0, 1, 100)  #data which should have 100 elements with mean=0 and std=1 
print(data_points)
sm.qqplot(data_points, line ='45') # That data_points is normal distribution

py.show()
# Out:
# [ 0.00400399  2.18455747 -0.22052299  0.0159844   0.18214802  0.75283332
#  -1.0073458  -0.63127853 -1.91009167  0.47303733 -0.34534988 -1.49041138
#   0.63560595  0.42590929 -0.04987402  0.91293012  1.02177225  0.40533847
#  -0.19351853  0.728565    2.16365949 -1.00073285  0.10105892  0.10791347
#  -0.18295649 -0.20842579 -0.39294667 -0.1095324  -0.42818523 -0.71125567
#   0.00837068 -0.78463755 -1.08024102  0.61129358  0.41259155 -0.43937663
#   0.61535831  0.32062217 -0.21089883 -0.24729601 -1.05350402 -1.44065231
#   0.59211048  0.70052778 -1.32384777 -0.74844168  0.45323546 -1.0177959
#  -1.34419507  0.86912211 -0.79072677  1.59856431 -0.42314509 -0.16484884
#   0.4751782   0.27582845  0.89086719  0.09858354  1.42775397  0.77169478
#  -0.12731215  0.05988357  1.27644086 -0.27607523  0.88571628  0.61495957
#   1.17225668  0.08401747  0.17655723  1.36983872 -0.72009011  0.42000102
#  -0.3141142  -1.45337701 -1.28052463 -1.12466716 -0.25003319 -2.27435408
#   1.21003514  1.3340476  -0.86579466  0.96736239  0.54767469  0.15055928
#  -1.15285402 -0.96033518  0.09852    -0.47440103  1.08807463 -0.41061413
#  -0.90119123  1.13672243 -0.02018262  0.2206152  -0.67699286 -2.18583333
#   1.35720429 -1.28113293 -2.35194043  0.44205906]

# %% [markdown]
# # Hypothesis testing

# %% [markdown]
# # Z test

# %%
# There is a claim that average age of IT male professionals in Bangalore is 35 years.
#H0: Average age is 35 years
#Ha: age is not 35 years

# %%
# z test
data=[36,25,26,27,33,32,37,27,46,28,29,25,27,28,34,35]
from statsmodels.stats.weightstats import ztest
z,p=ztest(data,value=35)
print("z=",z,"p=",p)
# Out:
# z= -2.8638715163428405 p= 0.004184977258998268

# %%
# At 5% level of significance, we reject null hypothesis because p<alpha i.e p<0.05
# We accept alternate hypothesis

# %% [markdown]
# # T-test

# %%
# T-test
# Botanist claims that average height of certain species is 15 inches.
#H0:avearge height is 15 inches
#Ha:average height is not 15 inches.

# %%
data=[14,14,16,13,12,17,15,14,15,13,15,14]
from scipy import stats
t,p=stats.ttest_1samp(data,15)
print("t=",t,"p=",p)
# Out:
# t= -1.6848470783484626 p= 0.12014460742498101

# %%
# At 5% level of significance, we accept the null hypothesis since p>alpha.

# %% [markdown]
# # Paired T-test

# %%
# Students score before and after attending study programs are same.
# H0: scores are same
# Ha : scores are different

# %%
pre_test=[88,82,93,75,72,81,67,91,83,79,80,90,91]
post_test=[91,84,88,90,87,92,95,78,89,84,93,94,98]
t,p=stats.ttest_rel(pre_test,post_test)
print("t=",t,"p=",p)
# Out:
# t= -2.503112816173455 p= 0.027756426983475475

# %%
# we reject H0 at 5% level of significance. since p<0.05

# %% [markdown]
# # Anova test
# '''A researcher recruits 30 students to participate in a study. The students are randomly assigned to use one of three studying techniques for the next three weeks to prepare for an exam. At the end of the three weeks, all of the students take the same test.'''

# %%
# H0: scores are same
# H1: scores are different

# %%
b=2.2/2
b
# Out:
# 1.1

# %%
g1=[85,86,88,75,78,94,98,79,71,80]
g2=[91,92,65,74,72,69,80,81,56,86]
g3=[72,45,87,65,57,89,60,55,62,80]


from scipy.stats import f_oneway
anova,p=f_oneway(g1,g2,g3)
print("anova=",anova,"p=",p)
# Out:
# anova= 4.786946736684172 p= 0.01661880053808376

# %%
#At 5% of level of significance, we reject null hypothesis since p<0.05
